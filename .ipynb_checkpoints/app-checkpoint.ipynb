# %%
from flask import Flask, render_template, request
import requests

app = Flask(__name__)


API_KEY = 'AIzaSyDcflPmpLyNcLQh5jhEmfinl6_1NsEzSrk'
CHANNEL_ID = 'UCT0s92hGjqLX6p7qY9BBrSA'


# Home Route
@app.route('/')
def home():
    return render_template('index.html')

# Academics Route
@app.route('/academics')
def academics():
    return render_template('academics.html')

# Contact Us Route
@app.route('/contact', methods=['GET', 'POST'])
def contact():
    if request.method == 'POST':
        name = request.form['name']
        email = request.form['email']
        message = request.form['message']
        # Handle the contact form submission (save to database, send email, etc.)
        return render_template('contact.html', success=True)
    return render_template('contact.html')

# Gallery Route
@app.route('/gallery')
def gallery():
    return render_template('gallery.html')

# Teachers Pillars Route
@app.route('/teachers')
def teachers():
    return render_template('teachers.html')


# Elearning videos

def get_videos(page_token=None):
    base_url = 'https://www.googleapis.com/youtube/v3/search'
    params = {
        'key': API_KEY,
        'channelId': CHANNEL_ID,
        'part': 'snippet',
        'maxResults': 5,
        'order': 'date',  # Optional: Order by date
        'pageToken': page_token  # Token for next/previous page
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"API Error: {response.status_code}, {response.text}")
        return None

@app.route('/elearning')
def elearning():
    page_token = request.args.get('pageToken', None)
    videos_data = get_videos(page_token)

    if videos_data:
        videos = [
            {
                'title': item['snippet']['title'],
                'videoId': item['id']['videoId'] if 'videoId' in item['id'] else None,
                'thumbnail': item['snippet']['thumbnails']['medium']['url'],
                'description': item['snippet']['description']
            }
            for item in videos_data.get('items', [])
            if item['id']['kind'] == 'youtube#video'
        ]
        return render_template(
            'elearning.html',
            videos=videos,
            next_page_token=videos_data.get('nextPageToken'),
            prev_page_token=videos_data.get('prevPageToken')
        )
    else:
        return "Error fetching videos."


if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [30/Nov/2024 21:22:37] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:37] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:37] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:40] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:41] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:41] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:44] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:44] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:44] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:48] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:48] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:48] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:52] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:52] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:55] "GET /academics HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:55] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:57] "GET /contact HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:57] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:59] "GET /gallery HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:22:59] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:59] "GET /static/images/school_event1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:22:59] "GET /static/images/school_event2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:00] "GET /static/images/school_event3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:01] "GET /teachers HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:01] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:01] "GET /static/img/teacher3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:01] "GET /static/img/teacher4.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:01] "GET /static/img/teacher2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:02] "GET /static/img/teacher1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:03] "GET /teachers HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:04] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:04] "GET /static/img/teacher4.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:04] "GET /static/img/teacher3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:04] "GET /static/img/teacher2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:04] "GET /static/img/teacher1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:05] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:05] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:08] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:08] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:08] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:11] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:11] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:18] "GET /teachers HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:18] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:18] "GET /static/img/teacher1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:18] "GET /static/img/teacher2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:18] "GET /static/img/teacher3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:18] "GET /static/img/teacher4.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:39] "GET /teachers HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:39] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:39] "GET /static/img/teacher1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:39] "GET /static/img/teacher2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:40] "GET /static/img/teacher3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:40] "GET /static/img/teacher4.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:42] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:42] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:44] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:45] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:45] "GET /static/images/building.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:47] "GET /elearning HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Nov/2024 21:23:47] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Nov/2024 21:23:47] "GET /static/images/building.jpg HTTP/1.1" 304 -
